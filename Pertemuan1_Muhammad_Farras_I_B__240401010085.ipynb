# %%
#Nama   : Muhammad Farras Ibnu Budiyanto
#NIM    : 240401010085
#Kelas  : IF404

#================================================
#PERTEMUAN PERTAMA: NOTEBOOK PERTAMA DATA SCIENCE
#================================================

#SEL 1: Output sederhana
print("Halo, data science")
print("Selamat datang di mata kuliah pengantar data science")

#SEL 2: Variabel dan tipe data dasar
nama = "Muhammad Farras Ibnu Budiyanto" #tipe data string
angkatan = 2024                         #tipe data integer
ipk = 3.14                              #tipe data float (untuk menyimpan nilai desimal)
aktif = True                            #tipe data boolean

print (f"Nama     : {nama}")
print (f"Angkatan : {angkatan}")
print (f"IPK      : {ipk}")
print (f"Aktif    : {aktif}")

#SELL 3: List dan perulangan
tools = ["Python", "Google Colab", "Jupiter Notebook", "Git.hub"]
print ("\nTools Data Science yang akan kita pelajari: ")
for i, tool in enumerate(tools, 1):
  print (f"{i}. {tools}")

#SEL 4: Fungsi Sederhana
def perkenalan(nama, prodi, angkatan):
    """Fungsi untuk menampilkan perkenalan mahasiswa."""
    return f"Perkenalkan, nama Saya {nama} dari {prodi}, angkatan {angkatan}."

hasil = perkenalan("Muhammad Farras Ibnu Budiyanto", "Teknik Informatika", 2024)
print(hasil)


##Kesimpulan
#Apa saja yang dipelajari: Mengenal dasar pilar Data Science dan mengenal serta mengenal dan mempraktikkan sintaks dasar python.
#Apa saja yang ditemui: Puthon memiliki sifat "dynamic typing" yang sangat praktis untuk mengolah data jika dibandingkan dengan C+ yang harus mendeklarasikan tipe data terlebih dahulu.
#Pertanyaan yang Muncul: Bagaimana cara mengimplementasikan Python secara lebih komples untuk manipulasi data.
# Out:
# Halo, data science
# Selamat datang di mata kuliah pengantar data science
# Nama     : Muhammad Farras Ibnu Budiyanto
# Angkatan : 2024
# IPK      : 3.14
# Aktif    : True
#
# Tools Data Science yang akan kita pelajari:
# 1. ['Python', 'Google Colab', 'Jupiter Notebook', 'Git.hub']
# 2. ['Python', 'Google Colab', 'Jupiter Notebook', 'Git.hub']
# 3. ['Python', 'Google Colab', 'Jupiter Notebook', 'Git.hub']
# 4. ['Python', 'Google Colab', 'Jupiter Notebook', 'Git.hub']
# Perkenalkan, nama Saya Muhammad Farras Ibnu Budiyanto dari Teknik Informatika, angkatan 2024.
